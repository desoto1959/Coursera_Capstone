# %% [markdown]
# # The Battle of the Neigbourhoods - Berlin

# %% [markdown]
# In this notebook we collect the neighbourhoods of Berlin from a wikepedia webpage.
# After cleaning the Neighbourhood data, it will be enriched with the geographical coordinates.

# %% [markdown]
# ## Importing libraries

# %%
# !pip install beautifulsoup4
# !pip install lxml
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner

from bs4 import BeautifulSoup # Library for scraping webpage
from IPython.display import display_html # Library for displaying HTML

#!pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from geopy.extra.rate_limiter import RateLimiter # ratelimiter for stopping if it takes to long to get the geocodes

# Library for saving en reading data from the project
from project_lib import Project

print('Importing ready!')
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from beautifulsoup4) (2.0.1)
# Requirement already satisfied: lxml in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (4.5.1)
# Importing ready!

# %% [markdown]
# ## Retreive neighbourhoods of Berlin from Wikipedia webpage

# %%
# Get webpage
source = requests.get('https://de.wikipedia.org/wiki/Verwaltungsgliederung_Berlins').text
# Scrape webpage
soup = BeautifulSoup(source,'lxml')
# Check title of webpage
print(soup.title)
# Get table from webpage
html_table = str(soup.table)
# Display table
display_html(html_table,raw=True)
# Out:
# <title>Verwaltungsgliederung Berlins – Wikipedia</title>
# <table class="wikitable sortable zebra" style="text-align:center">
# <tbody><tr class="hintergrundfarbe6">
# <th>Nr.
# </th>
# <th>Bezirk<br/>
# </th>
# <th class="unsortable">Ortsteile
# </th>
# <th>Fläche<br/>in km²<br/>
# </th>
# <th>Einwohner<sup class="reference" id="cite_ref-Bevölkerung_2-0"><a href="#cite_note-Bevölkerung-2">[2]</a></sup><br/><small>(31. Dezember 2019)</small><br/>
# </th>
# <th>Einwohner<br/>pro km²<br/><small>(31. Dezember 2019)</small>
# </th>
# <th class="unsortable">Bezirks­bürger­meister<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
# </th>
# <th class="unsortable">Karte
# </th></tr>
# <tr>
# <td>1
# </td>
# <td align="left"><b><span style="display:none;">Mitte</span><a class="image" href="/wiki/Datei:Coat_of_arms_of_borough_Mitte.svg" title="Berlin"><img alt="Berlin" data-file-height="846" data-file-width="572" decoding="async" height="30" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Coat_of_arms_of_borough_Mitte.svg/20px-Coat_of_arms_of_borough_Mitte.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Coat_of_arms_of_borough_Mitte.svg/30px-Coat_of_arms_of_borough_Mitte.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Coat_of_arms_of_borough_Mitte.svg/40px-Coat_of_arms_of_borough_Mitte.svg.png 2x" width="20"/></a> <a href="/wiki/Bezirk_Mitte" title="Bezirk Mitte">Mitte</a></b>
# </td>
# <td align="left">0101 <a href="/wiki/Berlin-Mitte" title="Berlin-Mitte">Mitte</a><br/>0102 <a href="/wiki/Berlin-Moabit" title="Berlin-Moabit">Moabit</a><br/>0103 <a href="/wiki/Berlin-Hansaviertel" title="Berlin-Hansaviertel">Hansaviertel</a><br/>0104 <a href="/wiki/Berlin-Tiergarten" title="Berlin-Tiergarten">Tiergarten</a><br/>0105 <a href="/wiki/Berlin-Wedding" title="Berlin-Wedding">Wedding</a><br/>0106 <a href="/wiki/Berlin-Gesundbrunnen" title="Berlin-Gesundbrunnen">Gesundbrunnen</a>
# </td>
# <td><span style="visibility:hidden;">0</span>39,47
# </td>
# <td>385.748
# </td>
# <td><span style="visibility:hidden;">0</span>9.773
# </td>
# <td align="left"><a href="/wiki/Stephan_von_Dassel" title="Stephan von Dassel">Stephan von Dassel</a> (<a href="/wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen_Berlin" title="Bündnis 90/Die Grünen Berlin">Grüne</a>)
# </td>
# <td><span class="coordinates plainlinks-print" id="Bezirk_Mitte"><a class="external text" href="https://geohack.toolforge.org/geohack.php?params=52.516666666667_N_13.366666666667_E_region:DE-BE_type:city(385748)&amp;pagename=Verwaltungsgliederung_Berlins&amp;language=de&amp;title=Bezirk+Mitte" rel="nofollow"><span title="Bezirk Mitte">Lage</span></a></span><span class="geo noexcerpt" style="display:none"><span class="body"></span><span class="latitude">52.516666666667</span><span class="longitude">13.366666666667</span><span class="elevation"></span></span><br/><a class="image" href="/wiki/Datei:Berlin_Mitte.svg"><img alt="Berlin Mitte.svg" data-file-height="252" data-file-width="271" decoding="async" height="84" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Berlin_Mitte.svg/90px-Berlin_Mitte.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Berlin_Mitte.svg/135px-Berlin_Mitte.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Berlin_Mitte.svg/180px-Berlin_Mitte.svg.png 2x" width="90"/></a>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td align="left"><span style="white-space:nowrap"><b><span style="display:none;">Friedrichshain-Kreuzberg</span><a class="image" href="/wiki/Datei:Coat_of_arms_of_borough_Friedrichshain-Kreuzberg.svg" title="Berlin"><img alt="Berlin" data-file-height="846" data-file-width="572" decoding="async" height="30" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c0/Coat_of_arms_of_borough_Friedrichshain-Kreuzberg.svg/20px-Coat_of_arms_of_borough_Friedrichshain-Kreuzberg.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c0/Coat_of_arms_of_borough_Friedrichshain-Kreuzberg.svg/30px-Coat_of_arms_of_borough_Friedrichshain-Kreuzberg.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c0/Coat_of_arms_of_borough_Friedrichshain-Kreuzberg.svg/40px-Coat_of_arms_of_borough_Friedrichshain-Kreuzberg.svg.png 2x" width="20"/></a> <a href="/wiki/Bezirk_Friedrichshain-Kreuzberg" title="Bezirk Friedrichshain-Kreuzberg"><span style="white-space:nowrap;">Friedrichshain-Kreuzberg</span></a></b></span>
# </td>
# <td align="left">0201 <a href="/wiki/Berlin-Friedrichshain" title="Berlin-Friedrichshain">Friedrichshain</a><br/>0202 <a href="/wiki/Berlin-Kreuzberg" title="Berlin-Kreuzberg">Kreuzberg</a>
# </td>
# <td><span style="visibility:hidden;">0</span>20,16
# </td>
# <td>290.386
# </td>
# <td>14.404
# </td>
# <td align="left"><a href="/wiki/Monika_Herrmann" title="Monika Herrmann">Monika Herrmann</a> (<a href="/wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen_Berlin" title="Bündnis 90/Die Grünen Berlin">Grüne</a>)
# </td>
# <td><span class="coordinates plainlinks-print" id="Bezirk_Friedrichshain-Kreuzberg"><a class="external text" href="https://geohack.toolforge.org/geohack.php?params=52.5_N_13.433333333333_E_region:DE-BE_type:city(290386)&amp;pagename=Verwaltungsgliederung_Berlins&amp;language=de&amp;title=Bezirk+Friedrichshain-Kreuzberg" rel="nofollow"><span title="Bezirk Friedrichshain-Kreuzberg">Lage</span></a></span><span class="geo noexcerpt" style="display:none"><span class="body"></span><span class="latitude">52.5</span><span class="longitude">13.433333333333</span><span class="elevation"></span></span><br/><a class="image" href="/wiki/Datei:Berlin_Friedrichshain-Kreuzberg.svg"><img alt="Berlin Friedrichshain-Kreuzberg.svg" data-file-height="185" data-file-width="246" decoding="async" height="68" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/86/Berlin_Friedrichshain-Kreuzberg.svg/90px-Berlin_Friedrichshain-Kreuzberg.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/86/Berlin_Friedrichshain-Kreuzberg.svg/135px-Berlin_Friedrichshain-Kreuzberg.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/86/Berlin_Friedrichshain-Kreuzberg.svg/180px-Berlin_Friedrichshain-Kreuzberg.svg.png 2x" width="90"/></a>
# </td></tr>
# <tr>
# <td>3
# </td>
# <td align="left"><b><span style="display:none;">Pankow</span><a class="image" href="/wiki/Datei:Coat_of_arms_of_borough_Pankow.svg" title="Berlin"><img alt="Berlin" data-file-height="846" data-file-width="572" decoding="async" height="30" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/27/Coat_of_arms_of_borough_Pankow.svg/20px-Coat_of_arms_of_borough_Pankow.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/27/Coat_of_arms_of_borough_Pankow.svg/30px-Coat_of_arms_of_borough_Pankow.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/27/Coat_of_arms_of_borough_Pankow.svg/40px-Coat_of_arms_of_borough_Pankow.svg.png 2x" width="20"/></a> <a href="/wiki/Bezirk_Pankow" title="Bezirk Pankow">Pankow</a></b>
# </td>
# <td align="left">0301 <a href="/wiki/Berlin-Prenzlauer_Berg" title="Berlin-Prenzlauer Berg">Prenzlauer Berg</a><br/>0302 <a href="/wiki/Berlin-Wei%C3%9Fensee" title="Berlin-Weißensee">Weißensee</a><br/>0303 <a href="/wiki/Berlin-Blankenburg" title="Berlin-Blankenburg">Blankenburg</a><br/>0304 <a href="/wiki/Berlin-Heinersdorf" title="Berlin-Heinersdorf">Heinersdorf</a><br/>0305 <a href="/wiki/Berlin-Karow" title="Berlin-Karow">Karow</a><br/>0306 <a href="/wiki/Berlin-Stadtrandsiedlung_Malchow" title="Berlin-Stadtrandsiedlung Malchow">Stadtrandsiedlung Malchow</a><br/>0307 <a href="/wiki/Berlin-Pankow" title="Berlin-Pankow">Pankow</a><br/>0308 <a href="/wiki/Berlin-Blankenfelde" title="Berlin-Blankenfelde">Blankenfelde</a><br/>0309 <a href="/wiki/Berlin-Buch" title="Berlin-Buch">Buch</a><br/>0310 <a href="/wiki/Berlin-Franz%C3%B6sisch_Buchholz" title="Berlin-Französisch Buchholz">Französisch Buchholz</a><br/>0311 <a href="/wiki/Berlin-Niedersch%C3%B6nhausen" title="Berlin-Niederschönhausen">Niederschönhausen</a><br/>0312 <a href="/wiki/Berlin-Rosenthal" title="Berlin-Rosenthal">Rosenthal</a><br/>0313 <a href="/wiki/Berlin-Wilhelmsruh" title="Berlin-Wilhelmsruh">

# %%
# Create a list from the HTML table
list = pd.read_html(html_table)
# Create a dataframe from that list
df = list[0]
df
# Out:
#     Nr.                      Bezirk  \
# 0     1                       Mitte
# 1     2    Friedrichshain-Kreuzberg
# 2     3                      Pankow
# 3     4  Charlottenburg-Wilmersdorf
# 4     5                     Spandau
# 5     6         Steglitz-Zehlendorf
# 6     7        Tempelhof-Schöneberg
# 7     8                    Neukölln
# 8     9            Treptow-Köpenick
# 9    10         Marzahn-Hellersdorf
# 10   11                 Lichtenberg
# 11   12               Reinickendorf
#
#                                             Ortsteile  Flächein km²  \
# 0   0101 Mitte0102 Moabit0103 Hansaviertel0104 Tie...          3947
# 1                   0201 Friedrichshain0202 Kreuzberg          2016
# 2   0301 Prenzlauer Berg0302 Weißensee0303 Blanken...         10301
# 3   0401 Charlottenburg0402 Wilmersdorf0403 Schmar...          6472
# 4   0501 Spandau0502 Haselhorst0503 Siemensstadt05...          9191
# 5   0601 Steglitz0602 Lichterfelde0603 Lankwitz060...         10250
# 6   0701 Schöneberg0702 Friedenau0703 Tempelhof070...          5309
# 7   0801 Neukölln0802 Britz0803 Buckow0804 Rudow08...          4493
# 8   0901 Alt-Treptow0902 Plänterwald0903 Baumschul...         16842
# 9   1001 Marzahn1002 Biesdorf1003 Kaulsdorf1004 Ma...          6174
# 10  1101 Friedrichsfelde1102 Karlshorst1103 Lichte...          5229
# 11  1201 Reinickendorf1202 Tegel1203 Konradshöhe12...          8946
#
#     Einwohner[2](31. Dezember 2019)  Einwohnerpro km²(31. Dezember 2019)  \
# 0                           385.748                                9.773
# 1                           290.386                               14.404
# 2                           409.335                                3.974
# 3                           343.592                                5.309
# 4                           245.197                                2.668
# 5                           310.071                                3.025
# 6                           350.984                                6.611
# 7                           329.917                                7.343
# 8                           273.689                                1.625
# 9                           269.967                                4.373
# 10                          294.201                                5.626
# 11                          266.408                                2.978
#
#          Bezirks­bürger­meister[3] Karte
# 0       Stephan von Dassel (Grüne)  Lage
# 1          Monika Herrmann (Grüne)  Lage
# 2           Sören Benn (Die Linke)  Lage
# 3           Reinhard Naumann (SPD)  Lage
# 4            Helmut Kleebank (SPD)  Lage
# 5   Cerstin Richter-Kotowski (CDU)  Lage
# 6         Angelika Schöttler (SPD)  Lage
# 7               Martin Hikel (SPD)  Lage
# 8                Oliver Igel (SPD)  Lage
# 9         Dagmar Pohle (Die Linke)  Lage
# 10      Michael Grunst (Die Linke)  Lage
# 11              Frank Balzer (CDU)  Lage

# %% [markdown]
# ## Cleaning en preparing the neighbourhoods

# %%
# Remove unnecessary columns
df.drop(df.iloc[:, 3:8], inplace=True, axis=1)
df
# Out:
#     Nr.                      Bezirk  \
# 0     1                       Mitte
# 1     2    Friedrichshain-Kreuzberg
# 2     3                      Pankow
# 3     4  Charlottenburg-Wilmersdorf
# 4     5                     Spandau
# 5     6         Steglitz-Zehlendorf
# 6     7        Tempelhof-Schöneberg
# 7     8                    Neukölln
# 8     9            Treptow-Köpenick
# 9    10         Marzahn-Hellersdorf
# 10   11                 Lichtenberg
# 11   12               Reinickendorf
#
#                                             Ortsteile
# 0   0101 Mitte0102 Moabit0103 Hansaviertel0104 Tie...
# 1                   0201 Friedrichshain0202 Kreuzberg
# 2   0301 Prenzlauer Berg0302 Weißensee0303 Blanken...
# 3   0401 Charlottenburg0402 Wilmersdorf0403 Schmar...
# 4   0501 Spandau0502 Haselhorst0503 Siemensstadt05...
# 5   0601 Steglitz0602 Lichterfelde0603 Lankwitz060...
# 6   0701 Schöneberg0702 Friedenau0703 Tempelhof070...
# 7   0801 Neukölln0802 Britz0803 Buckow0804 Rudow08...
# 8   0901 Alt-Treptow0902 Plänterwald0903 Baumschul...
# 9   1001 Marzahn1002 Biesdorf1003 Kaulsdorf1004 Ma...
# 10  1101 Friedrichsfelde1102 Karlshorst1103 Lichte...
# 11  1201 Reinickendorf1202 Tegel1203 Konradshöhe12...

# %%
# Rename columns (German to English)
df.rename(columns={'Bezirk': 'Borough', 'Ortsteile': 'Neighbourhood'}, inplace=True)
df
# Out:
#     Nr.                     Borough  \
# 0     1                       Mitte
# 1     2    Friedrichshain-Kreuzberg
# 2     3                      Pankow
# 3     4  Charlottenburg-Wilmersdorf
# 4     5                     Spandau
# 5     6         Steglitz-Zehlendorf
# 6     7        Tempelhof-Schöneberg
# 7     8                    Neukölln
# 8     9            Treptow-Köpenick
# 9    10         Marzahn-Hellersdorf
# 10   11                 Lichtenberg
# 11   12               Reinickendorf
#
#                                         Neighbourhood
# 0   0101 Mitte0102 Moabit0103 Hansaviertel0104 Tie...
# 1                   0201 Friedrichshain0202 Kreuzberg
# 2   0301 Prenzlauer Berg0302 Weißensee0303 Blanken...
# 3   0401 Charlottenburg0402 Wilmersdorf0403 Schmar...
# 4   0501 Spandau0502 Haselhorst0503 Siemensstadt05...
# 5   0601 Steglitz0602 Lichterfelde0603 Lankwitz060...
# 6   0701 Schöneberg0702 Friedenau0703 Tempelhof070...
# 7   0801 Neukölln0802 Britz0803 Buckow0804 Rudow08...
# 8   0901 Alt-Treptow0902 Plänterwald0903 Baumschul...
# 9   1001 Marzahn1002 Biesdorf1003 Kaulsdorf1004 Ma...
# 10  1101 Friedrichsfelde1102 Karlshorst1103 Lichte...
# 11  1201 Reinickendorf1202 Tegel1203 Konradshöhe12...

# %%
# Add column City to dataframe
df['City'] = 'Berlin'
df = df[ ['City'] + [ col for col in df.columns if col != 'City' ] ]
df
# Out:
#       City  Nr.                     Borough  \
# 0   Berlin    1                       Mitte
# 1   Berlin    2    Friedrichshain-Kreuzberg
# 2   Berlin    3                      Pankow
# 3   Berlin    4  Charlottenburg-Wilmersdorf
# 4   Berlin    5                     Spandau
# 5   Berlin    6         Steglitz-Zehlendorf
# 6   Berlin    7        Tempelhof-Schöneberg
# 7   Berlin    8                    Neukölln
# 8   Berlin    9            Treptow-Köpenick
# 9   Berlin   10         Marzahn-Hellersdorf
# 10  Berlin   11                 Lichtenberg
# 11  Berlin   12               Reinickendorf
#
#                                         Neighbourhood
# 0   0101 Mitte0102 Moabit0103 Hansaviertel0104 Tie...
# 1                   0201 Friedrichshain0202 Kreuzberg
# 2   0301 Prenzlauer Berg0302 Weißensee0303 Blanken...
# 3   0401 Charlottenburg0402 Wilmersdorf0403 Schmar...
# 4   0501 Spandau0502 Haselhorst0503 Siemensstadt05...
# 5   0601 Steglitz0602 Lichterfelde0603 Lankwitz060...
# 6   0701 Schöneberg0702 Friedenau0703 Tempelhof070...
# 7   0801 Neukölln0802 Britz0803 Buckow0804 Rudow08...
# 8   0901 Alt-Treptow0902 Plänterwald0903 Baumschul...
# 9   1001 Marzahn1002 Biesdorf1003 Kaulsdorf1004 Ma...
# 10  1101 Friedrichsfelde1102 Karlshorst1103 Lichte...
# 11  1201 Reinickendorf1202 Tegel1203 Konradshöhe12...

# %% [markdown]
# #### Convert the Neighbourhoods from 1 column to multiple rows

# %%
# Remove numbers the Neighbourhoods 
df['Neighbourhood'] = df['Neighbourhood'].str.replace('\d+', ';')
# Remove leading white space
df['Neighbourhood'] = df['Neighbourhood'].str.lstrip()
# Replace the white space 
df
# Out:
#       City  Nr.                     Borough  \
# 0   Berlin    1                       Mitte
# 1   Berlin    2    Friedrichshain-Kreuzberg
# 2   Berlin    3                      Pankow
# 3   Berlin    4  Charlottenburg-Wilmersdorf
# 4   Berlin    5                     Spandau
# 5   Berlin    6         Steglitz-Zehlendorf
# 6   Berlin    7        Tempelhof-Schöneberg
# 7   Berlin    8                    Neukölln
# 8   Berlin    9            Treptow-Köpenick
# 9   Berlin   10         Marzahn-Hellersdorf
# 10  Berlin   11                 Lichtenberg
# 11  Berlin   12               Reinickendorf
#
#                                         Neighbourhood
# 0   ; Mitte; Moabit; Hansaviertel; Tiergarten; Wed...
# 1                         ; Friedrichshain; Kreuzberg
# 2   ; Prenzlauer Berg; Weißensee; Blankenburg; Hei...
# 3   ; Charlottenburg; Wilmersdorf; Schmargendorf; ...
# 4   ; Spandau; Haselhorst; Siemensstadt; Staaken; ...
# 5   ; Steglitz; Lichterfelde; Lankwitz; Zehlendorf...
# 6   ; Schöneberg; Friedenau; Tempelhof; Mariendorf...
# 7      ; Neukölln; Britz; Buckow; Rudow; Gropiusstadt
# 8   ; Alt-Treptow; Plänterwald; Baumschulenweg; Jo...
# 9   ; Marzahn; Biesdorf; Kaulsdorf; Mahlsdorf; Hel...
# 10  ; Friedrichsfelde; Karlshorst; Lichtenberg; Fa...
# 11  ; Reinickendorf; Tegel; Konradshöhe; Heiligens...

# %%
# Generate for every Neighbourhood a new row
df1 = df.assign(Neighbourhood=df['Neighbourhood'].str.split(';')).explode('Neighbourhood')
#df1.drop(df1[df1.Neighbourhood == ''].index, inplace=True)
# Reset index
df1.reset_index(drop=True, inplace=True)
df1.head()
# Out:
#      City  Nr. Borough  Neighbourhood
# 0  Berlin    1   Mitte
# 1  Berlin    1   Mitte          Mitte
# 2  Berlin    1   Mitte         Moabit
# 3  Berlin    1   Mitte   Hansaviertel
# 4  Berlin    1   Mitte     Tiergarten

# %%
df1.shape
# Out:
# (109, 4)

# %%
# Remove Neighbourhoods without a value
df1.drop(df1[df1.Neighbourhood == ''].index, inplace=True)
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#       City  Nr.        Borough        Neighbourhood
# 0   Berlin    1          Mitte                Mitte
# 1   Berlin    1          Mitte               Moabit
# 2   Berlin    1          Mitte         Hansaviertel
# 3   Berlin    1          Mitte           Tiergarten
# 4   Berlin    1          Mitte              Wedding
# ..     ...  ...            ...                  ...
# 92  Berlin   12  Reinickendorf        Waidmannslust
# 93  Berlin   12  Reinickendorf               Lübars
# 94  Berlin   12  Reinickendorf             Wittenau
# 95  Berlin   12  Reinickendorf   Märkisches Viertel
# 96  Berlin   12  Reinickendorf          Borsigwalde
#
# [97 rows x 4 columns]

# %%
df1.shape
# Out:
# (97, 4)

# %% [markdown]
# ## Collecting the geographical coordinates for the neighbourhoods of Berlin

# %%
# Create a column 'Address' for getting the geographical coordinates
df1["Address"] = df1["Neighbourhood"] + ', ' +  df1["City"]
df1
# Out:
#       City  Nr.        Borough        Neighbourhood  \
# 0   Berlin    1          Mitte                Mitte
# 1   Berlin    1          Mitte               Moabit
# 2   Berlin    1          Mitte         Hansaviertel
# 3   Berlin    1          Mitte           Tiergarten
# 4   Berlin    1          Mitte              Wedding
# ..     ...  ...            ...                  ...
# 92  Berlin   12  Reinickendorf        Waidmannslust
# 93  Berlin   12  Reinickendorf               Lübars
# 94  Berlin   12  Reinickendorf             Wittenau
# 95  Berlin   12  Reinickendorf   Märkisches Viertel
# 96  Berlin   12  Reinickendorf          Borsigwalde
#
#                         Address
# 0                 Mitte, Berlin
# 1                Moabit, Berlin
# 2          Hansaviertel, Berlin
# 3            Tiergarten, Berlin
# 4               Wedding, Berlin
# ..                          ...
# 92        Waidmannslust, Berlin
# 93               Lübars, Berlin
# 94             Wittenau, Berlin
# 95   Märkisches Viertel, Berlin
# 96          Borsigwalde, Berlin
#
# [97 rows x 5 columns]

# %%
# Get the Geographical coordinates of 1 neighboorhood, to check if the geolocator works
address = 'Borsigwalde, Berlin'

geolocator = Nominatim(user_agent="neighbourhoud_explorer")

location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Berlin are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Berlin are 52.5840624, 13.3022741.

# %%
# 1 - convenient function to delay between geocoding calls
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
# 2- - create location column
df2 = df1.copy()
df2['location'] = df2['Address'].apply(geocode)

# %%
# 3 - create longitude, latitude and altitude from location column (returns tuple)
df2['point'] = df2['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
# Check for Neighbourhoods without geogrophical coordinates
print(df2.loc[df2["location"].isnull()].count())
df2.loc[df2["location"].isnull()]
# Out:
# City             0
# Nr.              0
# Borough          0
# Neighbourhood    0
# Address          0
# location         0
# point            0
# dtype: int64
# Empty DataFrame
# Columns: [City, Nr., Borough, Neighbourhood, Address, location, point]
# Index: []

# %%
# Remove the rows without geographical coordinats
df2.dropna(inplace=True)
df2.reset_index(drop=True, inplace=True)
df2
# Out:
#       City  Nr.        Borough        Neighbourhood  \
# 0   Berlin    1          Mitte                Mitte
# 1   Berlin    1          Mitte               Moabit
# 2   Berlin    1          Mitte         Hansaviertel
# 3   Berlin    1          Mitte           Tiergarten
# 4   Berlin    1          Mitte              Wedding
# ..     ...  ...            ...                  ...
# 92  Berlin   12  Reinickendorf        Waidmannslust
# 93  Berlin   12  Reinickendorf               Lübars
# 94  Berlin   12  Reinickendorf             Wittenau
# 95  Berlin   12  Reinickendorf   Märkisches Viertel
# 96  Berlin   12  Reinickendorf          Borsigwalde
#
#                         Address  \
# 0                 Mitte, Berlin
# 1                Moabit, Berlin
# 2          Hansaviertel, Berlin
# 3            Tiergarten, Berlin
# 4               Wedding, Berlin
# ..                          ...
# 92        Waidmannslust, Berlin
# 93               Lübars, Berlin
# 94             Wittenau, Berlin
# 95   Märkisches Viertel, Berlin
# 96          Borsigwalde, Berlin
#
#                                              location  \
# 0   (Mitte, Berlin, Deutschland, (52.5178855, 13.4...
# 1   (Moabit, Mitte, Berlin, Deutschland, (52.53010...
# 2   (Hansaviertel, Mitte, Berlin, 10557, Deutschla...
# 3   (Tiergarten, Mitte, Berlin, Deutschland, (52.5...
# 4   (Wedding, Mitte, Berlin, Deutschland, (52.5501...
# ..                                                ...
# 92  (Waidmannslust, Reinickendorf, Berlin, 13469, ...
# 93  (Lübars, Reinickendorf, Berlin, Deutschland, (...
# 94  (Wittenau, Reinickendorf, Berlin, Deutschland,...
# 95  (Märkisches Viertel, Reinickendorf, Berlin, 13...
# 96  (Borsigwalde, Reinickendorf, Berlin, Deutschla...
#
#                             point
# 0   (52.5178855, 13.4040601, 0.0)
# 1   (52.5301017, 13.3425422, 0.0)
# 2   (52.5191234, 13.3418725, 0.0)
# 3   (52.5097776, 13.3572597, 0.0)
# 4      (52.550123, 13.34197, 0.0)
# ..                            ...
# 92  (52.6080354, 13.3225327, 0.0)
# 93  (52.6146467, 13.3530197, 0.0)
# 94  (52.5912366, 13.3233195, 0.0)
# 95  (52.5993123, 13.3565324, 0.0)
# 96  (52.5840624, 13.3022741, 0.0)
#
# [97 rows x 7 columns]

# %%
df2.shape
# Out:
# (97, 7)

# %%
# 4 - split point column into latitude, longitude and altitude columns
df2[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df2['point'].tolist(), index=df2.index)
df2
# Out:
#       City  Nr.        Borough        Neighbourhood  \
# 0   Berlin    1          Mitte                Mitte
# 1   Berlin    1          Mitte               Moabit
# 2   Berlin    1          Mitte         Hansaviertel
# 3   Berlin    1          Mitte           Tiergarten
# 4   Berlin    1          Mitte              Wedding
# ..     ...  ...            ...                  ...
# 92  Berlin   12  Reinickendorf        Waidmannslust
# 93  Berlin   12  Reinickendorf               Lübars
# 94  Berlin   12  Reinickendorf             Wittenau
# 95  Berlin   12  Reinickendorf   Märkisches Viertel
# 96  Berlin   12  Reinickendorf          Borsigwalde
#
#                         Address  \
# 0                 Mitte, Berlin
# 1                Moabit, Berlin
# 2          Hansaviertel, Berlin
# 3            Tiergarten, Berlin
# 4               Wedding, Berlin
# ..                          ...
# 92        Waidmannslust, Berlin
# 93               Lübars, Berlin
# 94             Wittenau, Berlin
# 95   Märkisches Viertel, Berlin
# 96          Borsigwalde, Berlin
#
#                                              location  \
# 0   (Mitte, Berlin, Deutschland, (52.5178855, 13.4...
# 1   (Moabit, Mitte, Berlin, Deutschland, (52.53010...
# 2   (Hansaviertel, Mitte, Berlin, 10557, Deutschla...
# 3   (Tiergarten, Mitte, Berlin, Deutschland, (52.5...
# 4   (Wedding, Mitte, Berlin, Deutschland, (52.5501...
# ..                                                ...
# 92  (Waidmannslust, Reinickendorf, Berlin, 13469, ...
# 93  (Lübars, Reinickendorf, Berlin, Deutschland, (...
# 94  (Wittenau, Reinickendorf, Berlin, Deutschland,...
# 95  (Märkisches Viertel, Reinickendorf, Berlin, 13...
# 96  (Borsigwalde, Reinickendorf, Berlin, Deutschla...
#
#                             point   latitude  longitude  altitude
# 0   (52.5178855, 13.4040601, 0.0)  52.517885  13.404060       0.0
# 1   (52.5301017, 13.3425422, 0.0)  52.530102  13.342542       0.0
# 2   (52.5191234, 13.3418725, 0.0)  52.519123  13.341872       0.0
# 3   (52.5097776, 13.3572597, 0.0)  52.509778  13.357260       0.0
# 4      (52.550123, 13.34197, 0.0)  52.550123  13.341970       0.0
# ..                            ...        ...        ...       ...
# 92  (52.6080354, 13.3225327, 0.0)  52.608035  13.322533       0.0
# 93  (52.6146467, 13.3530197, 0.0)  52.614647  13.353020       0.0
# 94  (52.5912366, 13.3233195, 0.0)  52.591237  13.323320       0.0
# 95  (52.5993123, 13.3565324, 0.0)  52.599312  13.356532       0.0
# 96  (52.5840624, 13.3022741, 0.0)  52.584062  13.302274       0.0
#
# [97 rows x 10 columns]

# %%
# The code was removed by Watson Studio for sharing.

# %%
# Create an access to this project
project = Project.access(None,token,token)

# Save the collected Neighbourhoods and geographical data in project data bucket
project.save_data(file_name="geo_berlin.csv", data=df2.to_csv(index=False))
# Out:
# 2021-02-05 13:41:50,522 - __PROJECT_LIB__ - ERROR - failed to initialize ibmos2spark integration
# Traceback (most recent call last):
#   File "/opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/project_lib/storage/bcos.py", line 138, in _initialize_bcos2spark
#     import ibmos2spark
# ModuleNotFoundError: No module named 'ibmos2spark'
# {'file_name': 'geo_berlin.csv',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'applieddatasciencecapstone-donotdelete-pr-qfypp7va5rbswh',
#  'asset_id': '7dab6d22-c8e7-47b7-9e26-4d9ed97bb074'}
